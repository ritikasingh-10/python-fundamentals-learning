# %% [markdown]
# ## practice 1: input the 2 number and print their sums

# %%
num1 = int(input("enter any number"))
num2 = int(input("enter any number"))
sum = num1+num2
print(num1,"and ",num2,"sum is ",sum)
# Out:
# enter any number 2
# enter any number 2
# 2 and  2 sum is  4

# %% [markdown]
# ### practice 2: WAP to input side of a square & print its area.

# %%
#### area formula = a*
side = int(input("enter length"))
area=side*side
print("area of square",area)
# Out:
# enter length 4
# area of square 16

# %% [markdown]
# ### practice 3 : WAP to input 2 floting points numbers & print their average.

# %%
num1 = float(input("enter any number"))
num2 = float(input("enter any number"))
avg = (num1+num2)/2
print("avg of numbers is",avg)
# Out:
# enter any number 16.5
# enter any number 3.5
# avg of numbers is 10.0

# %% [markdown]
# ### practice 4 : write to input 2 int numbers , a and b and print true if a is greater than or equal to b. if not print false

# %%
num1 = int(input("enter any number"))
num2 = int(input("enter any number"))
print(num1>=num2)
# Out:
# enter any number 15
# enter any number 2
# True

# %% [markdown]
# ### Write a python program to find remainder when a number is divided by z.

# %%
num1 = int(input("enter any number"))
num2 = int(input("enter any number"))
div = num1%num2
print("reminder :",div)
# Out:
# enter any number 34
# enter any number 5
# reminder : 4

# %% [markdown]
# ### Check the type of variable assigned using input () function.

# %%
a = int(input("enter the value of a"))
print(type(a))
# Out:
# enter the value of a 22
# <class 'int'>
